# %% [markdown]
# # Exercise 2: Indexing and Probabilistic Retrieval
# The following code is modified from Exercise 1. It is used to construct the vocabulary and vectorize the documents and query.

# %%
from nltk.stem import PorterStemmer, WordNetLemmatizer
import nltk
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel
import string
from nltk.corpus import stopwords
import math
from collections import Counter
import numpy as np
nltk.download('stopwords')
nltk.download('punkt')



stemmer = PorterStemmer()

# Tokenize, stem a document
def tokenize(text):
    text = "".join([ch for ch in text if ch not in string.punctuation])
    tokens = nltk.word_tokenize(text)
    return " ".join([stemmer.stem(word.lower()) for word in tokens])

# Read a list of documents from a file. Each line in a file is a document
with open("bread.txt") as f:
# with open("epfldocs.txt") as f:
    content = f.readlines()
original_documents = [x.strip() for x in content] 
documents = [tokenize(d).split() for d in original_documents]

# create the vocabulary
vocabulary = set([item for sublist in documents for item in sublist])
vocabulary = [word for word in vocabulary if word not in stopwords.words('english')]
vocabulary.sort()

# compute IDF, storing idf values in a dictionary
def idf_values(vocabulary, documents):
    idf = {}
    num_documents = len(documents)
    for i, term in enumerate(vocabulary):
        idf[term] = math.log(num_documents/sum(term in document for document in documents), math.e)
    return idf

# Function to generate the vector for a document (with normalisation)
def vectorize(document, vocabulary, idf):
    vector = [0]*len(vocabulary)
    counts = Counter(document)
    max_count = counts.most_common(1)[0][1]
    for i,term in enumerate(vocabulary):
        vector[i] = idf[term] * counts[term]/max_count
    return vector

# Function to compute cosine similarity
def cosine_similarity(v1,v2):
    sumxx, sumxy, sumyy = 0, 0, 0
    for i in range(len(v1)):
        x = v1[i]; y = v2[i]
        sumxx += x*x
        sumyy += y*y
        sumxy += x*y
    if sumxy == 0:
            result = 0
    else:
            result = sumxy/math.sqrt(sumxx*sumyy)
    return result

def vectorize_query(query, vocabulary, idf):
    q = query.split()
    q = [stemmer.stem(w) for w in q]
    query_vector = vectorize(q, vocabulary, idf)
    return query_vector
    
def search_vec(query, k):
    query_vector = vectorize_query(query, vocabulary, idf)
    scores = [[cosine_similarity(query_vector, document_vectors[d]), d] for d in range(len(documents))]
    scores.sort(key=lambda x: -x[0])
    ans = []
    indices = []
    for i in range(min(k,len(original_documents))):
        ans.append(original_documents[scores[i][1]])
        indices.append(scores[i][1])
    return ans, indices, query_vector

# Compute IDF values and vectors
idf = idf_values(vocabulary, documents)
document_vectors = [vectorize(s, vocabulary, idf) for s in documents]
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Arild\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Arild\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# ## Question 1 -  Distributed Information Retrieval
#
# In this exercise we implement a core process of Fagin's algorithm, the parallel scanning of the posting lists. Assume an aggregation function that returns the sum of the tf-idf scores given the terms in a document.
#
# We assume that the posting lists for each term of a retrieval system are running on a different node.
#
# We first create a dictionary $h$, where each entry of the dictionary corresponds to a posting list for a term, assumed to be hosted in a different node. Explore the structure of $h$, to understand it. We suggest to first use the simple collection breads.txt.

# %%
import numpy as np
import operator

doc_vecs = np.transpose(np.array(document_vectors))
h = {}
for i, term in enumerate(vocabulary):
    ha = {}
    for docj in range(len(original_documents)):
        tfidf = doc_vecs[i][docj]
        ha[docj] = tfidf
    sorted_ha = sorted(ha.items(), key=operator.itemgetter(1), reverse=True)
    h[term] = sorted_ha

# %%
h['art']
# Out:
# [(2, 1.6094379124341003), (0, 0.0), (1, 0.0), (3, 0.0), (4, 0.0)]

# %% [markdown]
# ### Complete the following function that implements the Fagin algorithm.

# %%
def fagin_algorithm(query, h, k, vocabulary):
    
    # Split and stem the query
    q = query.split()
    q = set([stemmer.stem(w) for w in q])
    query_term_cnt = len(q)
    
    # select the posting lists for the query terms
    posting_lists = {}
    for term in q:
        if term in h:
            posting_lists[term] = h[term]
    
    max_len = len(documents)
    
    # Traverse the selected posting lists until we found k documents that appear in ALL posting lists
    # This corresponds to phase 1 of Fagin's algorithm.
    # As a result you produce a dictionary documents_occurrences, with the document identifiers as keys, 
    # and the number of documents found as value.
    # We stop traversing the posting lists until we have found k documents that appear in ALL posting lists 
    # of the query terms
    
    documents_occurrences = {}

    names = posting_lists.keys()

    for i in range(max_len):
        for name in names:
            if posting_lists[name][i][1] != 0.0:
                try: documents_occurrences[posting_lists[name][i][0]] += 1
                except: documents_occurrences[posting_lists[name][i][0]] = 1
        appeared_in_all = sum([1 for val in documents_occurrences.values() if val==len(names)])
        if k == appeared_in_all: break
    print(documents_occurrences)

    # Retrieve for the found documents the tfidf values and add them up.
    # For simplicity, we do not distinguish the cases whether the values have already been retrieved in the 
    # previous phase, or whether we use random access to obtain those values
    
    tfidf = {}
    for d in documents_occurrences.keys():
        t = 0
        for term in q:
            t = t + dict(posting_lists[term])[d]
        tfidf[d] = t
        
    # Finally we compute the top-k documents and return the answer
    
    ans = sorted(tfidf.items(), key=lambda x:x[1], reverse = True)[:k]
    return ans


ans = fagin_algorithm("bread recipe", h, 6, vocabulary)
print(ans)
for document_id in ans:
    print(original_documents[document_id[0]])
# Out:
# {2: 1, 3: 2, 0: 2, 4: 1}
# [(3, 1.1394342831883648), (0, 0.5697171415941824), (2, 0.22314355131420976), (4, 0.11157177565710488)]
# Breads, Pastries, Pies, and Cakes: Quantity Baking Recipes
# How to Bake Breads Without Baking Recipes
# Numerical Recipes: The Art of Scientific Computing
# Pastry: A Book of Best French Pastry Recipes

# %% [markdown]
# Produce your own datasets to explore the behavior of the algorithm. Create a dataset such that for retrieving a 2 term query a total of 6 documents needs to be retrieved in the first phase of the algorithm (as in the example in the lecture).

# %% [markdown]
# ## Question 2: Probabilistic Retrieval
#
# Following the notation used in class, let us denote the set of terms by $T=\{k_i|i=1,...,m\}$, the set of documents by $D=\{d_j |j=1,...,n\}$, and let $d_i=(w_{1j},w_{2j},...,w_{mj})$. We are also given a query  $q=(w_{1q},w_{2q},...,w_{mq})$. In the lecture we studied that,
#
# $sim(q,d_j) = \sum^m_{i=1} \frac{w_{ij}}{|d_j|}\frac{w_{iq}}{|q|}$ .  (1)
#
# Another way of looking at the information retrieval problem is using a probabilistic approach. The probabilistic view of information retrieval consists of determining the conditional probability $P(q|d_j)$ that for a given document $d_j$ the query by the user is $q$. So, practically in probabilistic retrieval when a query $q$ is given, for each document it is evaluated how probable it is that the query is indeed relevant for the document, which results in a ranking of the documents.
#
# In order to relate vector space retrieval to a probabilistic view of information retrieval, we interpret the weights in Equation (1) as follows:
#
# -  $w_{ij}/|d_j|$ can be interpreted as the conditional probability $P(k_i|d_j)$ that for a given document $d_j$ the term $k_i$ is important (to characterize the document $d_j$).
#
# -  $w_{iq}/|q|$ can be interpreted as the conditional probability $P(q|k_i)$ that for a given term $k_i$ the query posed by the user is $q$. Intuitively, $P(q|k_i)$ gives the amount of importance given to a particular term while querying.
#
# With this interpretation you can rewrite Equation (1) as follows:
#
# $sim(q,d_j) = \sum^m_{i=1} P(k_i|d_j)P(q|k_i)$ (2)
#
# ### Question a
# Show that indeed with the probabilistic interpretation of weights of vector space retrieval, as given in Equation (2), the similarity computation in vector space retrieval results exactly in the probabilistic interpretation of information retrieval, i.e., $sim(q,d_j)= P(q|d_j)$.
# Given that $d_j$ and $q$ are conditionally independent, i.e., $P(d_j \cap q|ki) = P(d_j|k_i)P(q|k_i)$. You can assume existence of joint probability density functions wherever required. (Hint: You might need to use Bayes theorem)

# %% [markdown]
# ### Question b
# Using the expression derived for $P(q|d_j)$ in (a), obtain a ranking (documents sorted in descending order of their scores) for the documents $P(k_i|d_1) = (0, 1/3, 2/3)$, $P(k_i|d_2) =(1/3, 2/3, 0)$, $P(k_i|d_3) = (1/2, 0, 1/2)$, and $P (k_i|d_4) = (3/4, 1/4, 0)$ and the query $P(q|k_i) = (1/5, 0, 2/3)$.

# %% [markdown]
# ### Question c

# %% [markdown]
#  Note that the model described in a. provides a probabilistic interpretation for vector space retrieval where weights are interpreted as probabilities . Compare to the probabilistic retrieval model based on language models introduced in the lecture and discuss the differences.

# %% [markdown]
# ## Question 3 - Inverted Files
#
# We learnt in the lecture that terms are typically stored in an inverted list. Now, in the inverted list, instead of only storing document identifiers of the documents in which the term appears, assume we also store an *offset* of the appearance of a term in a document. An $offset$ of a term $l_k$ given a document is defined as the number of words between the start of the document and $l_k$. Thus our inverted list is now:
#
# $l_k= \langle f_k: \{d_{i_1} \rightarrow [o_1,\ldots,o_{n_{i_1}}]\},
# \{d_{i_2} \rightarrow [o_1,\ldots,o_{n_{i_2}}]\}, \ldots,
# \{d_{i_k} \rightarrow [o_1,\ldots,o_{n_{i_k}}]\} \rangle$
#
# This means that in document $d_{i_1}$ term $l_k$ appears $n_{i_1}$ times and at offset $[o_1,,o_{n_{i_1}}]$, where $[o_1,,o_{n_{i_1}}]$ are sorted in ascending order, these type of indices are also known as term-offset indices. An example of a term-offset index is as follows:
#
# **Obama** = $⟨4 : {1 → [3]},{2 → [6]},{3 → [2,17]},{4 → [1]}⟩$
#
# **Governor** = $⟨2 : {4 → [3]}, {7 → [14]}⟩$
#
# **Election** = $⟨4 : {1 → [1]},{2 → [1,21]},{3 → [3]},{5 → [16,22,51]}⟩$
#
# Which is to say that the term **Governor** appear in 2 documents. In document 4 at offset 3, in document 7 at offset 14. Now let us consider the *SLOP/x* operator in text retrieval. This operator has the syntax: *QueryTerm1 SLOP/x QueryTerm2* finds occurrences of *QueryTerm1* within $x$ (but not necessarily in that order) words of *QueryTerm2*, where $x$ is a positive integer argument ($x \geq 1$). Thus $x = 1$ demands that *QueryTerm1* be adjacent to *QueryTerm2*.
#
# 1. List the set of documents that satisfy the query **Obama** *SLOP/2* **Election**.
# 2. List each set of values for which the query **Obama** *SLOP/x* **Election** has a different set of documents as answers (starting from $x = 1$).
# 3. Consider the general procedure for "merging" two term-offset inverted lists for a given document, to determine where the document satisfies a *SLOP/x* clause (since in general there will be many offsets at which each term occurs in a document). Let $L$ denote the total number of occurrences of the two terms in the document. Assume we have a pointer to the list of occurrences of each term and can move the pointer along this list. As we do so we check whether we have a hit for $SLOP/x$ (i.e. the $SLOP/x$ clause is satisfied). Each move of either pointer counts as a step. Based on this assumption is there a general "merging" procedure to determine whether the document satisfies a $SLOP/x$ clause, for which the following is true? Justify your answer.
#
#     1. The merge can be accomplished in a number of steps linear in $L$ regardless of $x$, and we can ensure that each pointer moves only to the right (i.e. forward).
#     2. The merge can be accomplished in a number of steps linear in $L$, but a pointer may be forced to move to the left (i.e. backwards).
#     3. The merge can require $x \times L$ steps in some cases.

# %% [markdown]
# ## Question 4: Create inverted files using MapReduce
# In this exercise, we want to create the inverted files using the MapReduce framework. Write the **map** and **reduce** function. Note that the code of **run_mapreduce** is just a simulation of the behavior of  map-reduce system.

# %%
with open("epfldocs.txt", encoding='utf-8') as f:
# with open("epfldocs.txt") as f:
    content = f.readlines()
original_documents = [x.strip() for x in content] 
documents = [tokenize(d).split() for d in original_documents]
docs_n_doc_ids = list(zip(range(len(documents)), documents))

# %%
# Take a pair (doc_id, content). Example: (0, ['how', 'to', 'bake', 'bread', 'without', 'bake', 'recip'])
# Return: list of (word, doc_id). Example: ('bake', 0)
# For simplicity, we assume each mapper handles a document
def map_function(doc_id, content):
    keyvals = []
    for word in content:
        keyvals.append((word, doc_id))
    return keyvals

# %%
# Take a list of pairs (word, doc_id). Example:  [('bake', 0), ('bake', 0), ('bake', 3)]
# Return: (word, frequency, list of document ids). Example ('bake', 3, [0, 0, 3])
# For simplicity, we assume each reducer handles a word
def reduce_function(lst):
    total = 0
    word = lst[0][0]
    doc_ids = []
    for w, doc_id in lst:
        assert(word==w) # Assume each reducer handles 1 word
        doc_ids.append(doc_id)
        total += 1
    return (word, total, doc_ids)

# %%
# We simulate the mapreduce framework by this function
def run_mapreduce(docs_n_doc_ids):
    # Map phase
    key_values = []
    for doc_id, doc_content in docs_n_doc_ids:
        key_values.extend(map_function(doc_id, doc_content))
    # Shuffle phase
    values = set(map(lambda x:x[0], key_values))
    grouped_key_values = [[y for y in key_values if y[0]==x] for x in values]
    # Reduce phase
    inverted_files = []
    for grouped_key_value in grouped_key_values:
        word, total, doc_ids = reduce_function(grouped_key_value)
        inverted_files.append((word, total, doc_ids))
    return inverted_files

# %%
run_mapreduce(docs_n_doc_ids)
# Out:
# [('significantli', 1, [193]),
#  ('about',
#   36,
#   [79,
#    102,
#    103,
#    126,
#    138,
#    163,
#    258,
#    274,
#    288,
#    310,
#    312,
#    323,
#    329,
#    341,
#    365,
#    390,
#    466,
#    481,
#    518,
#    526,
#    545,
#    608,
#    658,
#    663,
#    733,
#    743,
#    790,
#    799,
#    802,
#    804,
#    808,
#    859,
#    888,
#    904,
#    957,
#    987]),
#  ('seednight', 2, [156, 553]),
#  ('print', 1, [544]),
#  ('although', 1, [685]),
#  ('httpstcoa6lliu7txb', 1, [1055]),
#  ('medtech', 3, [84, 725, 726]),
#  ('nécessit', 1, [567]),
#  ('simultan', 1, [873]),
#  ('complex', 3, [29, 743, 1038]),
#  ('intelligenz', 1, [737]),
#  ('privaci', 3, [236, 262, 521]),
#  ('buccipergenova', 1, [639]),
#  ('cryptotoken', 1, [5]),
#  ('counterpart', 2, [216, 634]),
#  ('wissenschaft', 1, [743]),
#  ('naropen', 1, [415]),
#  ('25kmh', 1, [430]),
#  ('juridiqu', 3, [439, 840, 993]),
#  ('week',
#   16,
#   [77,
#    78,
#    124,
#    125,
#    125,
#    147,
#    399,
#    464,
#    466,
#    481,
#    516,
#    563,
#    623,
#    778,
#    973,
#    1006]),
#  ('orovil', 1, [1067]),
#  ('httpstcodntchhce5l', 1, [541]),
#  ('httpstcoezqkccdlqn', 1, [862]),
#  ('group', 9, [30, 64, 68, 336, 444, 599, 905, 1046, 1065]),
#  ('protein', 4, [159, 228, 795, 838]),
#  ('développé', 1, [129]),
#  ('croir', 1, [439]),
#  ('garfieldabh', 1, [1019]),
#  ('httpstcoh3jz6pjmta', 1, [544]),
#  ('examen', 2, [161, 495]),
#  ('follicular', 1, [35]),
#  ('noemiematthey', 1, [591]),
#  ('cheesecak', 1, [253]),
#  ('7047', 1, [161]),
#  ('tablet', 2, [435, 533]),
#  ('though', 1, [903]),
#  ('lornecanc', 1, [32]),
#  ('els', 3, [59, 791, 840]),
#  ('superglaz', 1, [231]),
#  ('httpstcotbclt4f9zn', 1, [1011]),
#  ('barrag', 2, [823, 1067]),
#  ('postfin', 1, [148]),
#  ('mattia', 1, [154]),
#  ('contrib', 1, [740]),
#  ('talent', 2, [301, 905]),
#  ('denfer', 1, [130]),
#  ('unesco', 1, [541]),
#  ('messestand', 1, [48]),
#  ('httpstcok8npxuuki8', 2, [883, 884]),
#  ('neighborhood', 1, [513]),
#  ('1000', 2, [279, 734]),
#  ('march', 7, [27, 39, 102, 492, 586, 651, 709]),
#  ('httpstcolxigtfhnyz', 1, [534]),
#  ('httpstcofow8wqhbka', 1, [431]),
#  ('entretien', 1, [463]),
#  ('prixbcninnovation17', 1, [568]),
#  ('vacanc', 1, [81]),
#  ('poursuit', 1, [568]),
#  ('compact', 1, [66]),
#  ('blockchainsummit', 1, [403]),
#  ('ha',
#   24,
#   [40,
#    65,
#    69,
#    104,
#    104,
#    115,
#    136,
#    142,
#    264,
#    364,
#    387,
#    407,
#    485,
#    533,
#    637,
#    778,
#    899,
#    903,
#    912,
#    948,
#    950,
#    963,
#    1014,
#    1036]),
#  ('przemek', 1, [960]),
#  ('swissembassyusa', 1, [313]),
#  ('métal', 1, [327]),
#  ('trouverez', 1, [342]),
#  ('vice', 1, [875]),
#  ('httpstcowb1xbztqqn', 1, [842]),
#  ('elektroden', 1, [701]),
#  ('drosophila', 1, [809]),
#  ('besson', 1, [855]),
#  ('highereduc', 1, [709]),
#  ('than', 12, [21, 64, 64, 111, 214, 355, 379, 531, 580, 778, 811, 858]),
#  ('adelio', 1, [419]),
#  ('httpstcos8zkriahbq', 1, [69]),
#  ('veganfood', 1, [253]),
#  ('sublim', 1, [843]),
#  ('correcteur', 1, [651]),
#  ('24', 2, [265, 990]),
#  ('allen', 1, [449]),
#  ('met', 2, [108, 269]),
#  ('précieux', 1, [279]),
#  ('intent', 1, [277]),
#  ('élément', 1, [311]),
#  ('swsx', 4, [21, 198, 580, 581]),
#  ('comité', 1, [304]),
#  ('professeur', 3, [118, 463, 958]),
#  ('httpstcol977bmopel', 1, [390]),
#  ('httpstcox7zx3pfsfv', 1, [845]),
#  ('httpstcozeu9qttta7', 1, [78]),
#  ('parti', 2, [592, 875]),
#  ('2018',
#   30,
#   [27,
#    28,
#    30,
#    32,
#    46,
#    137,
#    144,
#    168,
#    197,
#    202,
#    250,
#    263,
#    277,
#    350,
#    390,
#    393,
#    464,
#    465,
#    466,
#    512,
#    560,
#    586,
#    642,
#    688,
#    709,
#    719,
#    719,
#    801,
#    898,
#    1007]),
#  ('avez', 1, [1030]),
#  ('joetheshark', 1, [620]),
#  ('unforgett', 1, [576]),
#  ('newdawn', 1, [608]),
#  ('intracrani', 1, [290]),
#  ('esp', 1, [495]),
#  ('dernier', 1, [1066]),
#  ('down', 5, [173, 307, 719, 736, 854]),
#  ('disgrac', 1, [281]),
#  ('satellit', 1, [666]),
#  ('gibt', 1, [828]),
#  ('russian', 1, [1074]),
#  ('swissedtech', 3, [652, 1016, 1016]),
#  ('25novemb', 1, [774]),
#  ('unigenova', 1, [639]),
#  ('httpstcoilctlfatmt', 1, [340]),
#  ('ambrosusamb', 1, [587]),
#  ('tech4dev2018', 1, [350]),
#  ('limb', 1, [970]),
#  ('studi',
#   13,
#   [13, 73, 112, 142, 188, 290, 387, 494, 734, 755, 839, 845, 986]),
#  ('citat', 2, [63, 993]),
#  ('httpstcotw6q3kan5q', 1, [571]),
#  ('dautr', 2, [342, 682]),
#  ('focus', 2, [303, 507]),
#  ('commentair', 1, [12]),
#  ('invest', 5, [7, 146, 146, 146, 858]),
#  ('vd', 1, [86]),
#  ('idiap', 1, [859]),
#  ('ah', 2, [265, 265]),
#  ('httpstcorfp5dcojw4', 1, [651]),
#  ('thanksforthefollow', 2, [330, 819]),
#  ('brain',
#   15,
#   [6, 28, 84, 449, 497, 524, 534, 616, 713, 741, 741, 755, 755, 818, 904]),
#  ('httpstcoirx8jrn9uk', 1, [592]),
#  ('audiotactil', 1, [290]),
#  ('lancement', 2, [233, 1016]),
#  ('thought', 4, [111, 142, 355, 811]),
#  ('pensé', 1, [404]),
#  ('constitut', 1, [905]),
#  ('bauingenieurwissenschaften', 1, [309]),
#  ('décerné', 1, [710]),
#  ('cest', 6, [174, 265, 342, 837, 877, 920]),
#  ('plattform', 1, [384]),
#  ('diaspora', 1, [746]),
#  ('19052017', 1, [8]),
#  ('icymi', 1, [595]),
#  ('httpstcoxvevamgjgi', 1, [299]),
#  ('httpstcom4tvqnlcnm', 1, [130]),
#  ('httpstcoluzvtvhqzm', 1, [926]),
#  ('ultrasound', 1, [855]),
#  ('httpstcophz8wpvtn0', 1, [91]),
#  ('against', 4, [8, 175, 272, 746]),
#  ('httpstcouglltz05xk', 1, [850]),
#  ('associé', 2, [266, 1053]),
#  ('httpstcopqipgcl9wc', 1, [295]),
#  ('studio', 1, [453]),
#  ('clipair', 2, [711, 711]),
#  ('wave', 5, [44, 328, 527, 534, 908]),
#  ('d',
#   18,
#   [62,
#    128,
#    165,
#    243,
#    243,
#    243,
#    282,
#    447,
#    535,
#    543,
#    584,
#    610,
#    627,
#    723,
#    843,
#    861,
#    1040,
#    1067]),
#  ('enoch', 1, [189]),
#  ('problèm', 1, [823]),
#  ('passionnant', 1, [895]),
#  ('silicon', 4, [657, 672, 681, 949]),
#  ('reatch', 1, [572]),
#  ('content', 2, [259, 878]),
#  ('are',
#   51,
#   [13,
#    42,
#    50,
#    64,
#    80,
#    98,
#    139,
#    179,
#    191,
#    195,
#    203,
#    220,
#    223,
#    262,
#    264,
#    278,
#    278,
#    303,
#    321,
#    335,
#    341,
#    445,
#    458,
#    521,
#    525,
#    528,
#    536,
#    679,
#    685,
#    688,
#    699,
#    703,
#    703,
#    755,
#    767,
#    836,
#    838,
#    859,
#    859,
#    863,
#    871,
#    875,
#    897,
#    898,
#    909,
#    937,
#    938,
#    963,
#    995,
#    995,
#    1074]),
#  ('karbasi', 1, [195]),
#  ('absorpt', 1, [597]),
#  ('resolut', 1, [446]),
#  ('investglass', 1, [946]),
#  ('httpstcomrcygxna6g', 1, [229]),
#  ('httpstcowzvufmyxid', 1, [188]),
#  ('environ', 4, [104, 171, 292, 442]),
#  ('nathanquint', 1, [621]),
#  ('httpstcoz5czqofiyv', 1, [879]),
#  ('biophys', 2, [378, 795]),
#  ('httpstconkidutk1ag', 1, [681]),
#  ('send', 2, [641, 979]),
#  ('class', 3, [383, 429, 882]),
#  ('faculti', 1, [88]),
#  ('verg', 3, [234, 241, 387]),
#  ('vdtech',
#   46,
#   [53,
#    62,
#    110,
#    120,
#    132,
#    156,
#    177,
#    206,
#    228,
#    242,
#    256,
#    286,
#    332,
#    354,
#    364,
#    389,
#    405,
#    421,
#    432,
#    508,
#    562,
#    616,
#    623,
#    649,
#    652,
#    693,
#    718,
#    754,
#    788,
#    800,
#    801,
#    831,
#    838,
#    852,
#    865,
#    882,
#    883,
#    884,
#    885,
#    891,
#    902,
#    970,
#    997,
#    1027,
#    1048,
#    1050]),
#  ('httpstcoufbrxo4nqf', 1, [572]),
#  ('httpstcobuda7w2icm', 1, [629]),
#  ('httpstcon6d0dgje0v', 1, [790]),
#  ('calcul', 4, [545, 663, 685, 965]),
#  ('œuvr', 1, [456]),
#  ('cdu', 3, [1057, 1058, 1059]),
#  ('pest', 1, [485]),
#  ('flowersinria', 1, [735]),
#  ('out',
#   17,
#   [231,
#    296,
#    320,
#    323,
#    337,
#    371,
#    381,
#    411,
#    419,
#    601,
#    626,
#    688,
#    691,
#    959,
#    979,
#    1007,
#    1014]),
#  ('fischerconnect', 1, [492]),
#  ('bring', 3, [624, 648, 849]),
#  ('ordinateur', 1, [1051]),
#  ('coll', 1, [781]),
#  ('perl', 1, [886]),
#  ('12', 4, [264, 499, 525, 546]),
#  ('ecosystem', 1, [432]),
#  ('bravo', 4, [26, 63, 848, 1020]),
#  ('sierr', 1, [707]),
#  ('infini', 1, [889]),
#  ('pictur', 2, [559, 866]),
#  ('curti', 1, [148]),
#  ('thi',
#   38,
#   [58,
#    64,
#    66,
#    75,
#    103,
#    142,
#    151,
#    236,
#    240,
#    260,
#    267,
#    273,
#    278,
#    340,
#    374,
#    483,
#    516,
#    526,
#    576,
#    577,
#    585,
#    691,
#    717,
#    764,
#    765,
#    770,
#    802,
#    812,
#    816,
#    845,
#    869,
#    886,
#    909,
#    941,
#    946,
#    984,
#    999,
#    1002]),
#  ('butweet', 1, [916]),
#  ('neural', 1, [387]),
#  ('led', 1, [938]),
#  ('weekend', 6, [168, 307, 337, 342, 626, 899]),
#  ('braintovehicl', 1, [387]),
#  ('colorselect', 1, [36]),
#  ('bricol', 1, [781]),
#  ('httpstcoknvilhwpgb', 1, [426]),
#  ('first',
#   28,
#   [40,
#    44,
#    115,
#    125,
#    134,
#    148,
#    178,
#    203,
#    212,
#    248,
#    264,
#    293,
#    328,
#    360,
#    370,
#    407,
#    466,
#    507,
#    527,
#    563,
#    586,
#    607,
#    608,
#    716,
#    725,
#    908,
#    918,
#    1041]),
#  ('httpstcoqot0l2xucd', 1, [374]),
#  ('knight', 1, [99]),
#  ('cnp', 1, [247]),
#  ('green', 6, [152, 171, 473, 517, 853, 968]),
#  ('pentacen', 2, [303, 303]),
#  ('coréenn', 1, [706]),
#  ('noch', 1, [1015]),
#  ('melodi', 1, [750]),
#  ('nest', 1, [659]),
#  ('100kg', 1, [430]),
#  ('soumithchintala', 1, [501]),
#  ('lipid', 2, [638, 638]),
#  ('draw', 2, [738, 992]),
#  ('bench', 1, [694]),
#  ('kinet', 1, [248]),
#  ('httpstcofkue1gsy1z', 1, [558]),
#  ('règle', 1, [925]),
#  ('add', 1, [812]),
#  ('chôro', 1, [806]),
#  ('httpstcofclluldktk', 1, [571]),
#  ('physiqu', 2, [183, 568]),
#  ('highthroughput', 2, [545, 663]),
#  ('privat', 2, [499, 957]),
#  ('1ère', 1, [56]),
#  ('httpstcodtqvfwl3lj', 1, [433]),
#  ('sichert', 1, [425]),
#  ('polytechn', 1, [596]),
#  ('ucl', 1, [303]),
#  ('httpstcoarbz9t2dzx', 1, [181]),
#  ('httpstco3vujybmevd', 1, [341]),
#  ('found', 2, [732, 979]),
#  ('httpstcoh1tcmssnjb', 1, [674]),
#  ('morn', 2, [335, 964]),
#  ('largescal', 1, [469]),
#  ('sustainabilityweek', 1, [586]),
#  ('frauduleux', 1, [773]),
#  ('dépend', 1, [783]),
#  ('httpstcofp0yajwe9n', 1, [385]),
#  ('rayonsx', 1, [351]),
#  ('factori', 3, [141, 534, 619]),
#  ('ich', 2, [890, 954]),
#  ('mahgenev', 1, [243]),
#  ('here',
#   15,
#   [44, 103, 185, 262, 278, 348, 353, 466, 559, 576, 635, 678, 688, 743, 937]),
#  ('siemen', 1, [522]),
#  ('httpstco8owqib0csc', 1, [96]),
#  ('creativ', 1, [790]),
#  ('httpstcoqgkbwg220b', 1, [821]),
#  ('success', 7, [88, 166, 200, 263, 346, 391, 940]),
#  ('httpstcobcumzs50wo', 1, [64]),
#  ('turd', 1, [556]),
#  ('esthétiqu', 1, [1023]),
#  ('offer', 9, [60, 73, 138, 184, 246, 332, 606, 839, 914]),
#  ('ouvert', 1, [801]),
#  ('realen', 1, [737]),
#  ('porn', 1, [979]),
#  ('tini', 1, [1000]),
#  ('pbampb', 1, [156]),
#  ('puissant', 1, [921]),
#  ('second', 1, [488]),
#  ('sontil', 1, [921]),
#  ('demain', 4, [39, 243, 265, 1037]),
#  ('httpstcozjy1detl', 1, [993]),
#  ('jazz', 2, [1032, 1032]),
#  ('voir', 1, [644]),
#  ('alway', 1, [689]),
#  ('embopress', 1, [629]),
#  ('édition', 3, [202, 780, 902]),
#  ('httpstcoju8ess8cuj', 1, [798]),
#  ('cohort', 2, [56, 963]),
#  ('génétiqu', 2, [266, 783]),
#  ('showcas', 1, [990]),
#  ('gtgt', 1, [1063]),
#  ('violainese', 3, [80, 100, 685]),
#  ('johnantonaki', 1, [928]),
#  ('httpstcodkgmxia7tq', 1, [985]),
#  ('servir', 1, [682]),
#  ('court', 2, [475, 475]),
#  ('clip', 1, [794]),
#  ('beauti', 2, [458, 601]),
#  ('csl', 3, [61, 439, 939]),
#  ('réalitéaugmenté', 1, [251]),
#  ('sciencetm', 1, [943]),
#  ('roberv', 1, [710]),
#  ('resid', 1, [210]),
#  ('control', 7, [534, 668, 708, 838, 864, 867, 970]),
#  ('teilen', 1, [49]),
#  ('particl', 5, [44, 328, 527, 754, 908]),
#  ('lithographi', 1, [949]),
#  ('american', 1, [812]),
#  ('serviteur', 1, [548]),
#  ('paik', 2, [699, 699]),
#  ('httpstcoxrd9acgjgj', 1, [848]),
#  ('essenti', 1, [41]),
#  ('neu', 1, [890]),
#  ('gratzel', 1, [296]),
#  ('httpstcovvpdx19fim', 1, [864]),
#  ('aigencycom', 1, [898]),
#  ('berlin', 2, [422, 642]),
#  ('usa', 2, [963, 1067]),
#  ('httpstcov2cxkrcpvi', 1, [752]),
#  ('checklist', 1, [678]),
#  ('httpstcowmrbimab2g', 1, [664]),
#  ('threw', 1, [875]),
#  ('httpstcont7v9hkz3o', 1, [239]),
#  ('httpstcoopwuhvzs5d', 1, [896]),
#  ('hundr', 2, [899, 899]),
#  ('pierresern', 1, [687]),
#  ('educ', 7, [143, 177, 310, 310, 614, 639, 652]),
#  ('physiolog', 1, [489]),
#  ('oncl', 1, [927]),
#  ('symbionthost', 1, [55]),
#  ('hubaux', 2, [182, 724]),
#  ('httpstcoh3t8onsbo', 1, [146]),
#  ('promis', 3, [406, 486, 693]),
#  ('extens', 1, [899]),
#  ('valoris', 3, [844, 976, 977]),
#  ('trop', 2, [921, 1038]),
#  ('httpstcot4benvtkul', 1, [630]),
#  ('httpstcoe2ogm9ze7v', 1, [992]),
#  ('psichen', 1, [984]),
#  ('embl', 1, [674]),
#  ('direct', 3, [366, 874, 953]),
#  ('httpstco9jgkw9qz6x', 1, [550]),
#  ('trip', 1, [372]),
#  ('dr', 4, [105, 163, 226, 365]),
#  ('students🏅🏆', 1, [471]),
#  ('für', 9, [25, 49, 49, 167, 209, 384, 451, 721, 822]),
#  ('rest', 1, [325]),
#  ('photo', 3, [345, 507, 914]),
#  ('httpstcokxjjlgwmy5', 1, [87]),
#  ('tile', 1, [770]),
#  ('age', 4, [184, 186, 508, 833]),
#  ('censor', 1, [58]),
#  ('limpress', 1, [287]),
#  ('captur', 3, [575, 585, 770]),
#  ('ehr', 1, [25]),
#  ('stationn', 1, [687]),
#  ('httpstco1rc2edm3bc', 1, [913]),
#  ('❤️epflcultur', 1, [812]),
#  ('disrupt', 2, [521, 951]),
#  ('18h30', 1, [782]),
#  ('opticalfib', 3, [544, 712, 966]),
#  ('viventi', 1, [286]),
#  ('intel', 4, [234, 241, 533, 624]),
#  ('site', 5, [342, 705, 770, 800, 1039]),
#  ('risqu', 2, [185, 1048]),
#  ('cont', 1, [375]),
#  ('dario', 1, [318]),
#  ('innoc', 1, [122]),
#  ('personalis', 1, [758]),
#  ('1980', 1, [1069]),
#  ('imdepfl', 1, [57]),
#  ('versatil', 2, [17, 36]),
#  ('hill', 1, [736]),
#  ('httpstcoumkzw0yvo0', 1, [820]),
#  ('sélectionné', 1, [160]),
#  ('bluefactori', 1, [705]),
#  ('throw', 1, [641]),
#  ('httpstcorssxorvwmg', 1, [957]),
#  ('beethoven', 1, [1051]),
#  ('httpstcoboreqiexit', 1, [105]),
#  ('httpstcowsnmjekhmo', 1, [770]),
#  ('lo', 1, [1015]),
#  ('détermin', 1, [1031]),
#  ('httpstcoj25lllqmto', 1, [186]),
#  ('17h', 1, [967]),
#  ('applic', 7, [318, 334, 420, 688, 703, 1001, 1047]),
#  ('httpstco2bbtingzup', 1, [98]),
#  ('law', 1, [163]),
#  ('dune', 3, [183, 325, 356]),
#  ('étudiant·e·', 1, [1025]),
#  ('j', 2, [144, 945]),
#  ('countdown', 1, [868]),
#  ('httpstcoym6u32ngfp', 1, [566]),
#  ('foli', 1, [894]),
#  ('prend', 1, [705]),
#  ('httpstcoedkac9gul3', 1, [71]),
#  ('mrd', 1, [822]),
#  ('foi', 2, [548, 842]),
#  ('emr', 1, [484]),
#  ('lâge', 1, [202]),
#  ('httpstcovsh31g6vpl', 1, [56]),
#  ('sefaward', 1, [721]),
#  ('restitut', 1, [63]),
#  ('dnasequenc', 1, [159]),
#  ('dynam', 3, [66, 805, 959]),
#  ('httpstcofs7tdpbfsp', 1, [636]),
#  ('archivch', 1, [183]),
#  ('tf1lejt', 2, [244, 302]),
#  ('pan', 1, [172]),
#  ('introductori', 1, [34]),
#  ('racist', 1, [979]),
#  ('mechan', 6, [44, 512, 607, 607, 753, 809]),
#  ('avril4', 1, [202]),
#  ('gagner', 2, [279, 325]),
#  ('cowork', 1, [253]),
#  ('httpstcogk95auonyf', 1, [717]),
#  ('école', 2, [913, 1062]),
#  ('httpstcoovcxbizfdj', 1, [466]),
#  ('silvia', 1, [322]),
#  ('modestinogroup', 1, [626]),
#  ('feder', 5, [54, 596, 641, 675, 950]),
#  ('httpstcovzvmpcj3hv', 1, [102]),
#  ('therapeut', 1, [972]),
#  ('extinct', 1, [112]),
#  ('metal', 1, [115]),
#  ('never', 1, [910]),
#  ('httpstcojjpc1puyum', 2, [9, 774]),
#  ('httpstcojqle5pexa4', 1, [35]),
#  ('déjà', 2, [168, 996]),
#  ('live', 7, [17, 95, 112, 180, 257, 589, 992]),
#  ('mainten', 3, [307, 567, 1019]),
#  ('soldout', 1, [655]),
#  ('deephot', 1, [79]),
#  ('siraganyan', 1, [608]),
#  ('bolo', 2, [698, 698]),
#  ('pecub', 1, [1035]),
#  ('trump', 3, [556, 620, 1054]),
#  ('httpstcohdf05qrhiu', 1, [154]),
#  ('gregoir', 1, [114]),
#  ('httpstcoofhq1oxs4n', 1, [719]),
#  ('goal', 1, [126]),
#  ('httpstcomc2d0l1xrw', 1, [101]),
#  ('httpstcoeuir5wfkca', 1, [470]),
#  ('sol', 1, [710]),
#  ('encrypt', 1, [930]),
#  ('httpstcohwhyyevln4', 1, [987]),
#  ('40', 1, [1047]),
#  ('polymtl', 1, [654]),
#  ('yeux', 1, [924]),
#  ('httpstco4r7b6cemhk', 1, [849]),
#  ('qualifi', 1, [308]),
#  ('franz', 1, [633]),
#  ('elaudierlaudi', 1, [530]),
#  ('tomorrow', 11, [68, 72, 91, 156, 301, 503, 513, 656, 743, 760, 772]),
#  ('httpstcosnvl20jkaf', 1, [812]),
#  ('region', 1, [672]),
#  ('httpstcorhuhh0jm97', 1, [885]),
#  ('languag', 1, [792]),
#  ('détecter', 1, [892]),
#  ('electron', 3, [504, 865, 903]),
#  ('httpstcogyh0xlimff', 1, [704]),
#  ('growth', 1, [143]),
#  ('cryptosecur', 2, [213, 479]),
#  ('gründet', 1, [384]),
#  ('fsrm', 1, [1005]),
#  ('deputi', 1, [293]),
#  ('portrait', 1, [779]),
#  ('httpstco3jd6ff6a9z', 1, [191]),
#  ('life', 4, [30, 201, 593, 849]),
#  ('factor', 2, [170, 494]),
#  ('httpstcobmpozyou0x', 1, [922]),
#  ('httpstcoeadcnn0urq', 1, [882]),
#  ('turn', 4, [333, 360, 396, 722]),
#  ('httpstcothtcylrmtn', 1, [162]),
#  ('board', 3, [60, 359, 950]),
#  ('suhaibfahmi', 1, [909]),
#  ('httpstco1fat8de575', 1, [967]),
#  ('uighur', 1, [746]),
#  ('publicli', 1, [80]),
#  ('auront', 1, [924]),
#  ('santhanam', 1, [748]),
#  ('gamelab🕹rtstribu', 1, [893]),
#  ('acquir', 1, [318]),
#  ('httpstcoockxeddtcn', 1, [935]),
#  ('long', 4, [26, 246, 948, 1012]),
#  ('masschallengech', 3, [143, 247, 587]),
#  ('romandi', 1, [1027]),
#  ('formul', 1, [740]),
#  ('measurecomput', 1, [80]),
#  ('chees', 2, [587, 587]),
#  ('httpstcoapgzetdcu', 1, [614]),
#  ('authorprofil', 1, [550]),
#  ('had', 4, [746, 899, 1046, 1065]),
#  ('peter', 1, [957]),
#  ('inflight', 1, [318]),
#  ('verantwortung', 1, [105]),
#  ('httpstcovp03plbbr7', 1, [982]),
#  ('beerdecod', 1, [416]),
#  ('bright', 1, [671]),
#  ('httpstco5vujmpeatm', 1, [469]),
#  ('come',
#   14,
#   [38, 68, 156, 206, 301, 358, 368, 420, 556, 581, 595, 671, 679, 754]),
#  ('field', 4, [264, 611, 648, 850]),
#  ('grave', 1, [922]),
#  ('idiapch', 1, [507]),
#  ('dies', 1, [451]),
#  ('experiment', 1, [79]),
#  ('practition', 2, [33, 946]),
#  ('si', 4, [12, 61, 877, 877]),
#  ('regul', 1, [833]),
#  ('😷😝', 1, [919]),
#  ('geomicrobiolog', 1, [555]),
#  ('laperrouza', 1, [900]),
#  ('tobia', 1, [293]),
#  ('popular', 3, [407, 490, 1056]),
#  ('spieopticsphoton', 2, [317, 757]),
#  ('store', 1, [217]),
#  ('michan', 1, [323]),
#  ('cmi', 1, [225]),
#  ('httpstcompplaahj3x', 1, [1056]),
#  ('ladhul', 1, [219]),
#  ('persist', 1, [859]),
#  ('httpstcomzlm3v0ki', 1, [1010]),
#  ('httpstco4hmazta9qa', 1, [49]),
#  ('discuss', 9, [68, 107, 120, 270, 291, 320, 381, 572, 724]),
#  ('voyagebachelor', 1, [369]),
#  ('latsi', 1, [288]),
#  ('chez', 2, [922, 927]),
#  ('httpstcolmp8ss9czw', 1, [1004]),
#  ('facad', 1, [155]),
#  ('lespac', 1, [570]),
#  ('parent', 1, [791]),
#  ('alpin', 4, [171, 388, 462, 786]),
#  ('httpstcoytpwpwdbg', 1, [710]),
#  ('httpstcoybkxlwpuow', 1, [348]),
#  ('doesnt', 1, [1002]),
#  ('epfllts5', 1, [855]),
#  ('startupfit', 2, [286, 891]),
#  ('httpstcoou16d36it9', 1, [171]),
#  ('httpstcoaaiitfl6ji', 1, [741]),
#  ('gamechang', 1, [259]),
#  ('httpstcozi0urmutl5', 1, [279]),
#  ('la',
#   102,
#   [11,
#    11,
#    11,
#    12,
#    12,
#    16,
#    20,
#    26,
#    26,
#    26,
#    26,
#    26,
#    47,
#    51,
#    56,
#    61,
#    61,
#    81,
#    94,
#    118,
#    149,
#    149,
#    149,
#    157,
#    168,
#    182,
#    183,
#    197,
#    199,
#    202,
#    244,
#    252,
#    287,
#    300,
#    304,
#    304,
#    322,
#    325,
#    342,
#    345,
#    357,
#    362,
#    382,
#    383,
#    386,
#    386,
#    392,
#    404,
#    404,
#    452,
#    463,
#    526,
#    565,
#    566,
#    568,
#    584,
#    592,
#    603,
#    604,
#    610,
#    636,
#    644,
#    659,
#    706,
#    723,
#    766,
#    783,
#    784,
#    788,
#    788,
#    800,
#    806,
#    842,
#    844,
#    860,
#    874,
#    894,
#    895,
#    901,
#    902,
#    913,
#    919,
#    923,
#    929,
#    958,
#    958,
#    961,
#    976,
#    977,
#    978,
#    988,
#    996,
#    1016,
#    1016,
#    1018,
#    1022,
#    1030,
#    1030,
#    1042,
#    1054,
#    1066,
#    1066]),
#  ('ur', 1, [62]),
#  ('neighborhub', 1, [705]),
#  ('wto', 1, [637]),
#  ('ein', 5, [49, 209, 638, 721, 721]),
#  ('httpstco5zcwxyykdh', 1, [625]),
#  ('httpstcomjlq4d3rwm', 1, [773]),
#  ('sauver', 1, [123]),
#  ('se', 12, [26, 168, 244, 437, 495, 627, 653, 784, 815, 874, 896, 978]),
#  ('ibm', 1, [77]),
#  ('wonderqueen', 1, [764]),
#  ('nsf', 1, [697]),
#  ('intentionné', 1, [789]),
#  ('gafam', 1, [924]),
#  ('silentdisco', 1, [168]),
#  ('environn', 1, [162]),
#  ('httpstco06jmxdae2h', 1, [59]),
#  ('j2blather', 1, [899]),
#  ('submiss', 3, [350, 393, 578]),
#  ('m', 3, [731, 829, 945]),
#  ('test', 3, [80, 354, 564]),
#  ('cors', 1, [906]),
#  ('senior', 3, [485, 651, 1050]),
#  ('créé', 1, [1047]),
#  ('httpstcorm46e0v8gi', 1, [628]),
#  ('pist', 1, [1039]),
#  ('httpstcocqa8fqwqqg', 1, [619]),
#  ('quand', 4, [12, 183, 208, 823]),
#  ('httpstcoqogirkkqs', 1, [1066]),
#  ('pont', 1, [463]),
#  ('chanc', 2, [80, 688]),
#  ('dartseventeen', 2, [247, 615]),
#  ('httpstco2byw3asuc2', 1, [267]),
#  ('bottom', 1, [589]),
#  ('histon', 2, [66, 622]),
#  ('twiiceoffici', 2, [172, 649]),
#  ('financi', 2, [127, 291]),
#  ('healthi', 3, [131, 532, 997]),
#  ('httpstcocuixeajydh', 1, [83]),
#  ('dem', 1, [188]),
#  ('materialwissenschaft', 1, [309]),
#  ('httpstcov9rrdrv5jz', 1, [907]),
#  ('wpdl', 1, [916]),
#  ('therapi', 1, [529]),
#  ('httpstcob9tglxo4kd', 1, [838]),
#  ('httpstcoihyjn6az2i', 1, [242]),
#  ('squirrel', 1, [777]),
#  ('httpstco4qqqksoafm', 1, [942]),
#  ('httpstcolcs564yavr', 1, [98]),
#  ('alexandr', 1, [69]),
#  ('microbi', 1, [555]),
#  ('cool', 7, [86, 478, 661, 692, 764, 771, 810]),
#  ('httpstco6ixddicblu', 1, [964]),
#  ('nikola', 1, [805]),
#  ('1717', 1, [513]),
#  ('httpstcoqeimkjiqyy', 1, [534]),
#  ('bbca', 1, [1070]),
#  ('birthday', 3, [330, 360, 819]),
#  ('fret', 1, [959]),
#  ('origami', 3, [407, 407, 719]),
#  ('blown', 1, [323]),
#  ('sequencedirect', 1, [378]),
#  ('jamai', 1, [1038]),
#  ('more',
#   30,
#   [21,
#    64,
#    68,
#    102,
#    109,
#    110,
#    115,
#    169,
#    222,
#    236,
#    278,
#    278,
#    353,
#    426,
#    426,
#    482,
#    512,
#    515,
#    546,
#    577,
#    601,
#    623,
#    669,
#    688,
#    743,
#    790,
#    858,
#    897,
#    899,
#    1003]),
#  ('ngi4eu', 1, [549]),
#  ('findet', 1, [167]),
#  ('httpstcoomq1u70jz4', 1, [851]),
#  ('été', 2, [710, 710]),
#  ('jo', 2, [915, 1042]),
#  ('httpstcosiaunzx3f8', 1, [132]),
#  ('cecam', 1, [335]),
#  ('exist', 2, [68, 260]),
#  ('fifa', 1, [291]),
#  ('nation', 3, [54, 64, 480]),
#  ('might', 2, [340, 818]),
#  ('httpstco8staqsmknh', 1, [84]),
#  ('deliv', 2, [124, 223]),
#  ('doe', 3, [260, 613, 736]),
#  ('besar', 1, [1020]),
#  ('lexpertis', 1, [439]),
#  ('exosom', 1, [529]),
#  ('embark', 1, [177]),
#  ('unread', 1, [109]),
#  ('biologist', 1, [379]),
#  ('gro', 1, [922]),
#  ('microenvironment', 1, [32]),
#  ('wollen', 1, [701]),
#  ('éternel', 1, [570]),
#  ('julnicola', 1, [478]),
#  ('energyeffici', 1, [867]),
#  ('effort', 2, [26, 648]),
#  ('king', 1, [1012]),
#  ('face', 2, [112, 322]),
#  ('httpstconctmpw0ba3', 1, [37]),
#  ('venture2017', 2, [445, 974]),
#  ('linnov', 2, [902, 1054]),
#  ('cooper', 1, [71]),
#  ('petra', 1, [734]),
#  ('preserv', 1, [299]),
#  ('srg', 1, [144]),
#  ('httpstcopoi6gl8iyv', 1, [230]),
#  ('campu',
#   16,
#   [37,
#    40,
#    82,
#    130,
#    202,
#    342,
#    430,
#    455,
#    643,
#    812,
#    925,
#    996,
#    996,
#    1032,
#    1063,
#    1066]),
#  ('aleaf', 1, [237]),
#  ('end', 1, [980]),
#  ('ethen',
#   20,
#   [0,
#    3,
#    13,
#    54,
#    64,
#    139,
#    200,
#    267,
#    295,
#    391,
#    399,
#    489,
#    549,
#    560,
#    675,
#    686,
#    858,
#    934,
#    984,
#    995]),
#  ('herbac', 1, [446]),
#  ('parrain', 2, [729, 729]),
#  ('fête', 1, [277]),
#  ('httpstcotu6j8j44kl', 1, [42]),
#  ('last', 11, [77, 154, 175, 180, 481, 550, 607, 635, 719, 957, 987]),
#  ('meetlausann', 1, [744]),
#  ('team',
#   13,
#   [27, 178, 276, 364, 400, 481, 551, 561, 667, 746, 771, 986, 1014]),
#  ('like', 7, [80, 281, 413, 482, 542, 647, 979]),
#  ('assameet', 2, [294, 468]),
#  ('stuck', 1, [195]),
#  ('pie', 1, [383]),
#  ('stop', 5, [131, 134, 142, 532, 997]),
#  ('goodpowwow', 1, [915]),
#  ('létudi', 1, [893]),
#  ('jilasci', 1, [431]),
#  ('hybridesdenken', 1, [105]),
#  ('httpstcoxwnsg7vcei', 1, [149]),
#  ('httpstcom5ytgxf7ym', 1, [713]),
#  ('httpstcooziku5a3j3', 1, [788]),
#  ('httpstcovve1osjejv', 1, [363]),
#  ('expériment', 2, [456, 627]),
#  ('contr', 2, [603, 740]),
#  ('httpstcoaz7xlfk3da', 1, [961]),
#  ('gefahren', 1, [737]),
#  ('aud', 1, [118]),
#  ('lili', 1, [927]),
#  ('anticanc', 1, [211]),
#  ('mini3d', 1, [544]),
#  ('garcia', 1, [490]),
#  ('logitech', 1, [177]),
#  ('httpstcoerqa06qoiy', 1, [62]),
#  ('chang', 2, [768, 869]),
#  ('httpstcosnrtupk8po', 1, [118]),
#  ('millan', 1, [459]),
#  ('note', 2, [682, 840]),
#  ('httpstcomxk2y5brhf', 1, [339]),
#  ('microcityn', 1, [402]),
#  ('6pm', 1, [320]),
#  ('ou', 3, [815, 874, 1051]),
#  ('resumé', 1, [181]),
#  ('shoot', 1, [419]),
#  ('payot', 1, [846]),
#  ('boyarkin', 1, [661]),
#  ('we',
#   36,
#   [60,
#    65,
#    65,
#    78,
#    98,
#    108,
#    134,
#    134,
#    191,
#    203,
#    221,
#    223,
#    247,
#    264,
#    281,
#    307,
#    333,
#    346,
#    353,
#    414,
#    445,
#    572,
#    580,
#    601,
#    671,
#    703,
#    760,
#    802,
#    863,
#    886,
#    909,
#    935,
#    963,
#    1013,
#    1046,
#    1065]),
#  ('leuga', 1, [1018]),
#  ('scaday', 1, [862]),
#  ('biomolecul', 1, [695]),
#  ('gender', 2, [60, 646]),
#  ('httpstcogo0zwhqt8d', 1, [981]),
#  ('capssieu', 1, [549]),
#  ('🇨🇭', 2, [241, 382]),
#  ('cosi', 1, [265]),
#  ('httpstcog6qbwtrwga', 1, [402]),
#  ('hiiiiiighwaayyyyyyyi', 1, [787]),
#  ('past', 1, [296]),
#  ('aviv', 1, [658]),
#  ('httpstcoelpyorrs7', 1, [251]),
#  ('wife', 1, [195]),
#  ('httpstcogts6lu5tnr', 1, [989]),
#  ('photograph', 4, [44, 328, 527, 908]),
#  ('httpstcop8px0sqn4q', 1, [803]),
#  ('ar', 3, [241, 518, 521]),
#  ('httpstcodhsmrolyj7', 1, [429]),
#  ('httpstco856yhgi74j', 1, [58]),
#  ('slashandburn', 1, [808]),
#  ('32', 1, [492]),
#  ('solid', 1, [166]),
#  ('syndic', 1, [857]),
#  ('graduat', 3, [191, 257, 775]),
#  ('casestudi', 1, [955]),
#  ('s3', 3, [126, 126, 704]),
#  ('radiotelesuiss', 2, [889, 1067]),
#  ('zusammen', 1, [105]),
#  ('swissquotefr', 1, [538]),
#  ('httpstco5uemh3nxma', 1, [732]),
#  ('unineuchatel', 1, [402]),
#  ('subwavelength', 1, [36]),
#  ('httpstcopqqkry5ny9', 1, [69]),
#  ('rehabilit', 3, [440, 693, 852]),
#  ('theori', 2, [535, 750]),
#  ('machinelearn', 10, [127, 165, 165, 503, 587, 610, 667, 733, 765, 999]),
#  ('regist', 8, [23, 135, 180, 200, 464, 614, 704, 756]),
#  ('étoil', 1, [665]),
#  ('vidéo', 1, [893]),
#  ('klok', 1, [336]),
#  ('impress', 6, [256, 389, 507, 761, 852, 883]),
#  ('reward', 1, [948]),
#  ('httpstco6houuycwab', 1, [167]),
#  ('mettr', 2, [462, 1071]),
#  ('httpstcoqr5bho3ejh', 1, [794]),
#  ('swisseconom', 1, [1041]),
#  ('httpstco462ghoecml', 1, [1033]),
#  ('centr', 5, [16, 182, 182, 723, 947]),
#  ('wirkung', 1, [49]),
#  ('bernasconifosco', 1, [290]),
#  ('reçoit', 1, [752]),
#  ('strong', 5, [103, 116, 150, 187, 640]),
#  ('professorship', 1, [850]),
#  ('httpstcoocqae5drec', 1, [406]),
#  ('oskarfreysing', 1, [979]),
#  ('pic', 2, [375, 1005]),
#  ('rolexlearningcent', 6, [96, 168, 197, 749, 851, 872]),
#  ('wwim15igerslausann', 2, [475, 476]),
#  ('albrecht96', 1, [563]),
#  ('potenti', 6, [69, 112, 158, 547, 677, 734]),
#  ('said', 1, [938]),
#  ('faux', 1, [659]),
#  ('deconvolut', 2, [80, 100]),
#  ('itw', 2, [526, 1068]),
#  ('prof',
#   21,
#   [107,
#    107,
#    107,
#    119,
#    126,
#    157,
#    187,
#    223,
#    264,
#    275,
#    288,
#    296,
#    318,
#    419,
#    575,
#    699,
#    791,
#    903,
#    915,
#    1067,
#    1068]),
#  ('interdisciplinair', 1, [183]),
#  ('carbon', 2, [575, 918]),
#  ('kur', 1, [167]),
#  ('erc', 1, [717]),
#  ('httpstcoaa0crtmgnf', 1, [294]),
#  ('by',
#   79,
#   [4,
#    15,
#    22,
#    27,
#    35,
#    46,
#    53,
#    68,
#    68,
#    74,
#    75,
#    86,
#    98,
#    99,
#    104,
#    114,
#    126,
#    132,
#    145,
#    163,
#    164,
#    184,
#    193,
#    196,
#    222,
#    237,
#    239,
#    242,
#    248,
#    250,
#    260,
#    262,
#    275,
#    284,
#    292,
#    294,
#    303,
#    303,
#    314,
#    318,
#    323,
#    372,
#    376,
#    390,
#    416,
#    428,
#    468,
#    469,
#    480,
#    513,
#    521,
#    534,
#    573,
#    585,
#    586,
#    594,
#    596,
#    597,
#    607,
#    624,
#    666,
#    669,
#    678,
#    684,
#    720,
#    745,
#    748,
#    786,
#    790,
#    827,
#    833,
#    928,
#    953,
#    957,
#    959,
#    959,
#    1003,
#    1032,
#    1061]),
#  ('solair', 4, [51, 268, 913, 1023]),
#  ('sorbonneuniv', 1, [164]),
#  ('foresti', 1, [653]),
#  ('your',
#   19,
#   [75,
#    98,
#    141,
#    307,
#    348,
#    394,
#    397,
#    448,
#    539,
#    575,
#    593,
#    642,
#    776,
#    907,
#    930,
#    937,
#    941,
#    1006,
#    1033]),
#  ('rape', 2, [122, 979]),
#  ('mauric', 2, [360, 360]),
#  ('isabel', 1, [801]),
#  ('2030agenda', 1, [541]),
#  ('kiss', 1, [907]),
#  ('glisser', 1, [548]),
#  ('httpstcoqein9qwqol', 1, [968]),
#  ('proposé', 3, [261, 844, 862]),
#  ('soutien', 1, [996]),
#  ('afriquemagazin', 1, [1010]),
#  ('far', 1, [834]),
#  ('pleas', 2, [352, 640]),
#  ('exclusif', 1, [683]),
#  ('miniprojektor', 1, [241]),
#  ('httpstcor5vo6fuylg', 1, [896]),
#  ('collaboratif', 2, [304, 385]),
#  ('lucmeier', 1, [895]),
#  ('archaïqu', 1, [843]),
#  ('artist', 1, [534]),
#  ('hasard', 1, [651]),
#  ('arena', 1, [919]),
#  ('fourth', 1, [863]),
#  ('hess', 1, [1015]),
#  ('maschinenbau', 1, [309]),
#  ('apachemxnet', 1, [34]),
#  ('httpstcoe0libndjkc', 1, [671]),
#  ('mieux', 7, [383, 543, 610, 627, 976, 977, 978]),
#  ('africain', 2, [683, 1010]),
#  ('magnifiqu', 1, [1020]),
#  ('marion', 1, [824]),
#  ('cultureartsci', 1, [837]),
#  ('httpstcopeme43mdfn', 1, [140]),
#  ('traceepfl', 1, [69]),
#  ('httpstco99djfmjkt8', 1, [539]),
#  ('attent', 2, [773, 1049]),
#  ('cwarwarrior', 1, [810]),
#  ('edtechaccelch', 1, [222]),
#  ('changer', 1, [644]),
#  ('rencart', 1, [462]),
#  ('immers', 1, [444]),
#  ('luca', 1, [1069]),
#  ('thafid64', 1, [1071]),
#  ('claudiopagliara', 1, [530]),
#  ('vet', 1, [308]),
#  ('fractur', 1, [1030]),
#  ('httpstcosmknizeyip', 1, [898]),
#  ('unplug', 1, [333]),
#  ('gordon', 1, [88]),
#  ('httpstcodbgpv4sztp', 1, [747]),
#  ('fds2017', 1, [766]),
#  ('mang', 1, [927]),
#  ('httpstconz9kigfbn2', 1, [124]),
#  ('ground', 1, [872]),
#  ('httpstcomdanih1v5h', 1, [45]),
#  ('pepsico', 1, [522]),
#  ('baumann', 1, [613]),
#  ('proje…', 1, [93]),
#  ('httpstcok6brnizpdi', 1, [786]),
#  ('metoo', 1, [979]),
#  ('httpstcojqydabxwf7', 1, [293]),
#  ('httpstcoynzefgafiy', 1, [607]),
#  ('montagn', 1, [388]),
#  ('httpstcoiklrksjqn5', 1, [213]),
#  ('18h00', 1, [453]),
#  ('heterogen', 2, [734, 766]),
#  ('snsfch', 2, [288, 905]),
#  ('httpstco5mf6xxcaih', 1, [103]),
#  ('inscrivezv', 1, [929]),
#  ('httpstcokbirk356nn', 2, [150, 185]),
#  ('wait', 2, [255, 899]),
#  ('patient', 3, [566, 972, 1035]),
#  ('convers', 3, [681, 863, 911]),
#  ('jouer', 1, [983]),
#  ('7', 6, [167, 252, 390, 519, 631, 979]),
#  ('und', 9, [105, 309, 425, 443, 638, 638, 701, 721, 737]),
#  ('compet', 1, [21]),
#  ('beobsess', 1, [143]),
#  ('thoma', 3, [137, 223, 506]),
#  ('walli', 2, [185, 743]),
#  ('doug', 1, [293]),
#  ('httpstcohbayeuqajd', 1, [314]),
#  ('kippenberg', 1, [293]),
#  ('technew', 1, [414]),
#  ('prudenc', 1, [185]),
#  ('roboticist', 1, [102]),
#  ('façad', 7, [51, 152, 473, 517, 853, 913, 968]),
#  ('amparistech', 1, [654]),
#  ('thymioii', 5, [20, 554, 554, 652, 735]),
#  ('deconvolutionlab2', 2, [80, 100]),
#  ('httpstco6ztzov8ylh', 1, [837]),
#  ('ctmcecam', 1, [335]),
#  ('anniversari', 1, [762]),
#  ('vuill', 1, [107]),
#  ('revoir', 1, [12]),
#  ('ête', 1, [197]),
#  ('electrochem', 1, [676]),
#  ('httpstcoxaapgicva3', 1, [139]),
#  ('httpstcoqj7zbiiia6', 1, [372]),
#  ('access', 6, [107, 107, 348, 878, 911, 917]),
#  ('inscrit', 1, [161]),
#  ('httpstco6yp1ywa7ww', 1, [206]),
#  ('oxid', 1, [334]),
#  ('particularli', 1, [323]),
#  ('marché', 1, [162]),
#  ('bell', 2, [172, 829]),
#  ('httpstco5hwwdcahxr', 1, [206]),
#  ('forthcom', 1, [469]),
#  ('edaci', 3, [7, 495, 495]),
#  ('oh', 1, [620]),
#  ('4k', 1, [471]),
#  ('favorit', 1, [846]),
#  ('acadsci', 1, [311]),
#  ('make',
#   14,
#   [75, 110, 295, 485, 490, 516, 533, 667, 692, 704, 937, 941, 949, 1002]),
#  ('beltandroad1', 2, [598, 639]),
#  ('givaudan', 1, [522]),
#  ('everyon', 2, [59, 589]),
#  ('httpstcoudqn1rpspf', 1, [1051]),
#  ('encor', 3, [168, 402, 627]),
#  ('ma', 4, [261, 392, 752, 988]),
#  ('plenari', 2, [317, 951]),
#  ('🏆🙃😜👾🚀🎉', 1, [1]),
#  ('endosymbiont', 1, [809]),
#  ('cranfielduni', 1, [471]),
#  ('respons', 4, [13, 65, 314, 862]),
#  ('horizon2020ict', 1, [457]),
#  ('httpstcoimkcke7z3n', 1, [1034]),
#  ('flowcytometri', 1, [203]),
#  ('yunchul', 1, [210]),
#  ('nafld', 1, [298]),
#  ('gesundheit', 1, [638]),
#  ('belt', 1, [598]),
#  ('nobannowal', 1, [1054]),
#  ('brantut', 1, [431]),
#  ('lavoir', 1, [392]),
#  ('httpstcol86yujnipi', 1, [800]),
#  ('gillesjobin1', 1, [313]),
#  ('énergi', 1, [283]),
#  ('origin', 3, [284, 325, 866]),
#  ('🦈💦📸', 1, [345]),
#  ('httpstcoicgwb6puwo', 1, [597]),
#  ('expans', 1, [171]),
#  ('httpstcouy5r7w0a9r', 1, [886]),
#  ('httpstcojh2nndxm00', 1, [789]),
#  ('cyberintproject', 1, [746]),
#  ('sex', 1, [928]),
#  ('httpstcozl8ig3vbau', 1, [36]),
#  ('ft', 1, [972]),
#  ('uefa', 3, [128, 291, 992]),
#  ('httpstcos3j7vxdgy9', 1, [226]),
#  ('httpstcoaf6shy2cvv', 1, [373]),
#  ('début', 3, [47, 901, 1018]),
#  ('which', 4, [413, 791, 870, 903]),
#  ('onboard', 1, [666]),
#  ('httpstcoe2dcsoafrj', 1, [236]),
#  ('httpstcokm1p7dnpr4', 1, [919]),
#  ('2017',
#   24,
#   [48,
#    48,
#    63,
#    121,
#    154,
#    178,
#    265,
#    420,
#    422,
#    431,
#    538,
#    560,
#    609,
#    705,
#    730,
#    887,
#    929,
#    931,
#    934,
#    975,
#    1015,
#    1062,
#    1064,
#    1066]),
#  ('camp', 3, [619, 906, 963]),
#  ('httpstcobhlj5whmbc', 1, [424]),
#  ('bedsid', 1, [694]),
#  ('coorgan', 1, [250]),
#  ('parrot', 1, [318]),
#  ('révolut', 1, [627]),
#  ('darchiv', 1, [202]),
#  ('httpstco6haoskjtmz', 1, [201]),
#  ('stylu', 1, [676]),
#  ('lavieparisienn', 1, [190]),
#  ('get',
#   19,
#   [5,
#    211,
#    222,
#    348,
#    352,
#    390,
#    464,
#    554,
#    557,
#    649,
#    688,
#    719,
#    941,
#    953,
#    979,
#    985,
#    1006,
#    1046,
#    1065]),
#  ('wirklich', 1, [105]),
#  ('seoul', 1, [93]),
#  ('renew', 1, [442]),
#  ('lattendez', 1, [860]),
#  ('ai',
#   23,
#   [21,
#    27,
#    50,
#    97,
#    165,
#    181,
#    198,
#    236,
#    323,
#    414,
#    448,
#    501,
#    534,
#    580,
#    581,
#    610,
#    692,
#    722,
#    747,
#    765,
#    899,
#    946,
#    999]),
#  ('unistra', 1, [334]),
#  ('httpstcojtheq7sb9d', 1, [491]),
#  ('crew', 1, [474]),
#  ('httpstcoulurhrsqwi', 1, [353]),
#  ('httpstcotxqbyqdzsl', 1, [882]),
#  ('without', 4, [109, 221, 361, 750]),
#  ('cape', 1, [108]),
#  ('paralyz', 1, [970]),
#  ('unit', 1, [66]),
#  ('scolair', 1, [783]),
#  ('soulag', 2, [300, 837]),
#  ('aziz', 1, [55]),
#  ('httpstcoh0tw5auhlg', 1, [836]),
#  ('inspir', 9, [132, 264, 376, 390, 455, 464, 588, 738, 790]),
#  ('target', 3, [242, 519, 746]),
#  ('tuesday', 2, [623, 946]),
#  ('thebaltimoretim', 1, [814]),
#  ('httpstcoaxxf5tgqj3', 1, [692]),
#  ('uncertainti', 1, [613]),
#  ('combien', 1, [687]),
#  ('clinic', 1, [352]),
#  ('amit', 1, [469]),
#  ('ufcuniv', 1, [304]),
#  ('httpstcomftlolyolu', 1, [410]),
#  ('roi', 1, [98]),
#  ('thearkvalai', 1, [130]),
#  ('better', 1, [835]),
#  ('isrec', 1, [32]),
#  ('fight', 2, [229, 717]),
#  ('auspol', 1, [396]),
#  ('zusammenarbeit', 1, [425]),
#  ('fear', 1, [899]),
#  ('tesar', 2, [294, 468]),
#  ('httpstcof47bx1wyki', 1, [514]),
#  ('httpstcolznfvtycr7', 1, [645]),
#  ('rail', 1, [567]),
#  ('débrouillé', 1, [548]),
#  ('polair', 1, [636]),
#  ('prendr', 1, [345]),
#  ('larchitectur', 2, [462, 1068]),
#  ('httpstcocmujlvakjl', 1, [422]),
#  ('mot', 2, [548, 1043]),
#  ('julien', 1, [365]),
#  ('high', 6, [428, 446, 611, 637, 639, 1055]),
#  ('superb', 1, [386]),
#  ('from',
#   77,
#   [22,
#    30,
#    32,
#    59,
#    59,
#    83,
#    89,
#    100,
#    108,
#    164,
#    223,
#    227,
#    247,
#    260,
#    271,
#    276,
#    303,
#    318,
#    335,
#    359,
#    365,
#    365,
#    409,
#    413,
#    414,
#    416,
#    427,
#    427,
#    444,
#    464,
#    469,
#    481,
#    486,
#    499,
#    507,
#    515,
#    532,
#    535,
#    535,
#    545,
#    562,
#    563,
#    575,
#    587,
#    591,
#    593,
#    607,
#    608,
#    614,
#    615,
#    622,
#    630,
#    648,
#    655,
#    663,
#    694,
#    694,
#    712,
#    731,
#    734,
#    734,
#    735,
#    738,
#    765,
#    776,
#    831,
#    847,
#    849,
#    849,
#    855,
#    905,
#    930,
#    966,
#    992,
#    1013,
#    1033,
#    1064]),
#  ('mindblow', 1, [1014]),
#  ('nanoobjetsnanoparticul', 1, [978]),
#  ('difficult', 1, [115]),
#  ('samsam86', 1, [956]),
#  ('heluc', 2, [235, 569]),
#  ('cybathlon', 1, [178]),
#  ('beat', 1, [344]),
#  ('httpstco8rlp0zzhyb', 1, [0]),
#  ('httpstco3zvz8pwqlc', 1, [852]),
#  ('unibasel', 1, [346]),
#  ('httpstconpgbukjhbl', 1, [228]),
#  ('advertis', 1, [555]),
#  ('shortliv', 1, [66]),
#  ('sandec', 1, [975]),
#  ('evangelist', 1, [747]),
#  ('durabl', 1, [996]),
#  ('pattern', 2, [6, 387]),
#  ('entdeckt', 1, [451]),
#  ('septemb', 3, [679, 885, 887]),
#  ('httpstcokf6e0am2kb', 1, [51]),
#  ('complain', 1, [323]),
#  ('hightech', 2, [898, 901]),
#  ('httpstcovhb2r8q5am', 1, [555]),
#  ('tum', 1, [648]),
#  ('résistant', 2, [405, 424]),
#  ('fall', 2, [486, 984]),
#  ('emeritu', 1, [762]),
#  ('minh', 1, [658]),
#  ('falt', 1, [737]),
#  ('techcrunch', 3, [247, 615, 660]),
#  ('dfloreano', 1, [905]),
#  ('sfsch', 1, [148]),
#  ...]
